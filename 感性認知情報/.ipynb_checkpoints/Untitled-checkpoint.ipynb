# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, ), (0.5, ))])
trainset = torchvision.datasets.MNIST(root='./data', 
                                        train=True,
                                        download=True,
                                        transform=transform)
trainloader = torch.utils.data.DataLoader(trainset,
                                            batch_size=100,
                                            shuffle=True,
                                            num_workers=2)

testset = torchvision.datasets.MNIST(root='./data', 
                                        train=False, 
                                        download=True, 
                                        transform=transform)
testloader = torch.utils.data.DataLoader(testset, 
                                            batch_size=100,
                                            shuffle=False, 
                                            num_workers=2)

classes = tuple(np.linspace(0, 9, 10, dtype=np.uint8))
# Out:
# Using downloaded and verified file: ./data/MNIST/raw/train-images-idx3-ubyte.gz
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Using downloaded and verified file: ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Using downloaded and verified file: ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-27-e7df46ed77ad> in <module>
#      12                                         train=True,
#      13                                         download=True,
# ---> 14                                         transform=transform)
#      15 trainloader = torch.utils.data.DataLoader(trainset,
#      16                                             batch_size=100,
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/torchvision/datasets/mnist.py in __init__(self, root, train, transform, target_transform, download)
#      68
#      69         if download:
# ---> 70             self.download()
#      71
#      72         if not self._check_exists():
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/torchvision/datasets/mnist.py in download(self)
#     135         for url, md5 in self.resources:
#     136             filename = url.rpartition('/')[2]
# --> 137             download_and_extract_archive(url, download_root=self.raw_folder, filename=filename, md5=md5)
#     138
#     139         # process and save as torch files
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/torchvision/datasets/utils.py in download_and_extract_archive(url, download_root, extract_root, filename, md5, remove_finished)
#     262         filename = os.path.basename(url)
#     263
# --> 264     download_url(url, download_root, filename, md5)
#     265
#     266     archive = os.path.join(download_root, filename)
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/torchvision/datasets/utils.py in download_url(url, root, filename, md5)
#      95                 )
#      96             else:
# ---> 97                 raise e
#      98         # check integrity of downloaded file
#      99         if not check_integrity(fpath, md5):
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/torchvision/datasets/utils.py in download_url(url, root, filename, md5)
#      83             urllib.request.urlretrieve(
#      84                 url, fpath,
# ---> 85                 reporthook=gen_bar_updater()
#      86             )
#      87         except (urllib.error.URLError, IOError) as e:
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 503: Service Unavailable

# %%
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3) # 28x28x32 -> 26x26x32
        self.conv2 = nn.Conv2d(32, 64, 3) # 26x26x64 -> 24x24x64 
        self.pool = nn.MaxPool2d(2, 2) # 24x24x64 -> 12x12x64
        self.dropout1 = nn.Dropout2d()
        self.fc1 = nn.Linear(12 * 12 * 64, 128)
        self.dropout2 = nn.Dropout2d()
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.dropout1(x)
        x = x.view(-1, 12 * 12 * 64)
        x = F.relu(self.fc1(x))
        x = self.dropout2(x)
        x = self.fc2(x)
        return x

# %%
net = Net()

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
epochs = 5

for epoch in range(epochs):
    running_loss = 0.0
    for i, (inputs, labels) in enumerate(trainloader, 0):
        if i > 300:
            break
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 100 == 99:
            print('[{:d}, {:5d}] loss: {:.3f}'
                    .format(epoch + 1, i + 1, running_loss / 100))
            running_loss = 0.0
print('Finished Training')
# Out:
# [1,   100] loss: 2.209
# [1,   200] loss: 1.560
# [1,   300] loss: 0.822
# [2,   100] loss: 0.615
# [2,   200] loss: 0.547
# [2,   300] loss: 0.489
# [3,   100] loss: 0.437
# [3,   200] loss: 0.411
# [3,   300] loss: 0.385
# [4,   100] loss: 0.344
# [4,   200] loss: 0.366
# [4,   300] loss: 0.334
# [5,   100] loss: 0.310
# [5,   200] loss: 0.296
# [5,   300] loss: 0.290
# Finished Training

# %%
import copy

# %%
s_res_dict = [[0 for i in range(10)] for x in range(10)]

# %%
correct = 0
total = 0

with torch.no_grad():
    for (images, labels) in testloader:
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        for i in range(len(labels)):
            s_res_dict[int(labels[i])][int(predicted[i])] += 1
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
print('Accuracy: {:.2f} %%'.format(100 * float(correct/total)))
# Out:
# Accuracy: 66.29 %%

# %%
for k in range(len(s_res_dict)):
    s_res_dict[k] = [round(s_res_dict[k][i]/sum(s_res_dict[k]),3) for i in range(len(s_res_dict[k]))]

# %%
res_dict
# Out:
# [[0.979, 0.0, 0.004, 0.003, 0.003, 0.004, 0.003, 0.001, 0.003, 0.0],
#  [0.0, 0.98, 0.002, 0.004, 0.0, 0.0, 0.003, 0.002, 0.011, 0.0],
#  [0.007, 0.004, 0.955, 0.009, 0.002, 0.002, 0.005, 0.003, 0.013, 0.001],
#  [0.002, 0.001, 0.017, 0.946, 0.0, 0.012, 0.001, 0.007, 0.009, 0.006],
#  [0.001, 0.0, 0.006, 0.0, 0.945, 0.001, 0.007, 0.004, 0.004, 0.032],
#  [0.009, 0.001, 0.001, 0.018, 0.004, 0.929, 0.01, 0.002, 0.02, 0.004],
#  [0.007, 0.003, 0.003, 0.0, 0.01, 0.009, 0.963, 0.0, 0.003, 0.0],
#  [0.0, 0.011, 0.018, 0.013, 0.004, 0.001, 0.0, 0.933, 0.004, 0.018],
#  [0.004, 0.001, 0.009, 0.017, 0.005, 0.01, 0.008, 0.007, 0.935, 0.002],
#  [0.003, 0.004, 0.0, 0.01, 0.014, 0.007, 0.0, 0.012, 0.008, 0.943]]

# %%
df = pd.DataFrame(res_dict, index=index, columns=index)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colors

# %%
index = [i for i in range(10)]

# %%
df.style.background_gradient(cmap="Reds")
# Out:
# <style  type="text/css" >
#     #T_afc0f208_c51e_11eb_92d6_f104706c96b6row0_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row0_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row0_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row0_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row0_col6 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row0_col7 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row0_col8 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row0_col9 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row1_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row1_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row1_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row1_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row1_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row1_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row1_col6 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row1_col7 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row1_col8 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row1_col9 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row2_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row2_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row2_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row2_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row2_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row2_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row2_col6 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row2_col7 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row2_col8 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row2_col9 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row3_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row3_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row3_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row3_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row3_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row3_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row3_col6 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row3_col7 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row3_col8 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row3_col9 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row4_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row4_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row4_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row4_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row4_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row4_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row4_col6 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row4_col7 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row4_col8 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row4_col9 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row5_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row5_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row5_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row5_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row5_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row5_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row5_col6 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row5_col7 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row5_col8 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_afc0f208_c51e_11eb_92d6_f104706c96b6row5_col9 {
#             background-color:  #fff5f0;
#             color:  #000000;

# %%
new_res_dict = [s_res_dict[x] for x in range(10)]

# %%
for i in range(10):
    new_res_dict[i][i] = None

# %%
df = pd.DataFrame(new_res_dict, index=index, columns=index)
def background_gradient(s, m, M, cmap='PuBu', low=0, high=0):
    rng = M - m
    norm = colors.Normalize(m - (rng * low),
                            M + (rng * high))
    normed = norm(s.values)
    c = [colors.rgb2hex(x) for x in plt.cm.get_cmap(cmap)(normed)]
    return ['background-color: %s' % color for color in c]
df.style.apply(background_gradient,
               cmap='Reds',
               m=df.min().min(),
               M=df.max().max(),
               low=0,
               high=0.2)

#df.style.background_gradient(low=0.5, high=0,cmap="Reds")
# Out:
# <style  type="text/css" >
#     #T_4f84961a_c51e_11eb_92d6_f104706c96b6row0_col0 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row0_col1 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row0_col2 {
#             background-color:  #fee4d8;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row0_col3 {
#             background-color:  #fee8dd;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row0_col4 {
#             background-color:  #fee8dd;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row0_col5 {
#             background-color:  #fee4d8;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row0_col6 {
#             background-color:  #fee8dd;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row0_col7 {
#             background-color:  #fff1ea;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row0_col8 {
#             background-color:  #fee8dd;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row0_col9 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row1_col0 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row1_col1 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row1_col2 {
#             background-color:  #ffece4;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row1_col3 {
#             background-color:  #fee4d8;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row1_col4 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row1_col5 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row1_col6 {
#             background-color:  #fee8dd;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row1_col7 {
#             background-color:  #ffece4;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row1_col8 {
#             background-color:  #fcaf93;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row1_col9 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row2_col0 {
#             background-color:  #fdd0bc;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row2_col1 {
#             background-color:  #fee4d8;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row2_col2 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row2_col3 {
#             background-color:  #fcc1a8;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row2_col4 {
#             background-color:  #ffece4;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row2_col5 {
#             background-color:  #ffece4;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row2_col6 {
#             background-color:  #fedfd0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row2_col7 {
#             background-color:  #fee8dd;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row2_col8 {
#             background-color:  #fc9e80;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row2_col9 {
#             background-color:  #fff1ea;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row3_col0 {
#             background-color:  #ffece4;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row3_col1 {
#             background-color:  #fff1ea;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row3_col2 {
#             background-color:  #fb7c5c;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row3_col3 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row3_col4 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row3_col5 {
#             background-color:  #fca689;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row3_col6 {
#             background-color:  #fff1ea;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row3_col7 {
#             background-color:  #fdd0bc;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row3_col8 {
#             background-color:  #fcc1a8;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row3_col9 {
#             background-color:  #fdd7c6;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row4_col0 {
#             background-color:  #fff1ea;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row4_col1 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row4_col2 {
#             background-color:  #fdd7c6;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row4_col3 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row4_col4 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row4_col5 {
#             background-color:  #fff1ea;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row4_col6 {
#             background-color:  #fdd0bc;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row4_col7 {
#             background-color:  #fee4d8;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row4_col8 {
#             background-color:  #fee4d8;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row4_col9 {
#             background-color:  #b11218;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row5_col0 {
#             background-color:  #fcc1a8;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row5_col1 {
#             background-color:  #fff1ea;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row5_col2 {
#             background-color:  #fff1ea;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row5_col3 {
#             background-color:  #fb7555;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row5_col4 {
#             background-color:  #fee4d8;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row5_col5 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row5_col6 {
#             background-color:  #fcb89e;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row5_col7 {
#             background-color:  #ffece4;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row5_col8 {
#             background-color:  #f96245;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row5_col9 {
#             background-color:  #fee4d8;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row6_col0 {
#             background-color:  #fdd0bc;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row6_col1 {
#             background-color:  #fee8dd;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row6_col2 {
#             background-color:  #fee8dd;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row6_col3 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row6_col4 {
#             background-color:  #fcb89e;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row6_col5 {
#             background-color:  #fcc1a8;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row6_col6 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row6_col7 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row6_col8 {
#             background-color:  #fee8dd;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row6_col9 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row7_col0 {
#             background-color:  #fff5f0;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row7_col1 {
#             background-color:  #fcaf93;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row7_col2 {
#             background-color:  #fb7555;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row7_col3 {
#             background-color:  #fc9e80;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row7_col4 {
#             background-color:  #fee4d8;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row7_col5 {
#             background-color:  #fff1ea;
#         }    #T_4f84961a_c51e_11eb_92d6_f104706c96b6row7_col6 {
#             bac

# %%
df = pd.DataFrame(new_res_dict, index=index, columns=index)
def background_gradient(s, m, M, cmap='PuBu', low=0, high=0):
    rng = M - m
    norm = colors.Normalize(m - (rng * low),
                            M + (rng * high))
    normed = norm(s.values)
    c = [colors.rgb2hex(x) for x in plt.cm.get_cmap(cmap)(normed)]
    return ['background-color: %s' % color for color in c]
df.style.apply(background_gradient,
               cmap='Reds',
               m=df.min().min(),
               M=df.max().max(),
               low=0,
               high=0.2)

#df.style.background_gradient(low=0.5, high=0,cmap="Reds")
# Out:
# <style  type="text/css" >
#     #T_9a431230_c51e_11eb_92d6_f104706c96b6row0_col0 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row0_col1 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row0_col2 {
#             background-color:  #ffebe2;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row0_col3 {
#             background-color:  #feeae1;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row0_col4 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row0_col5 {
#             background-color:  #fff1ea;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row0_col6 {
#             background-color:  #fff4ee;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row0_col7 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row0_col8 {
#             background-color:  #fff1ea;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row0_col9 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row1_col0 {
#             background-color:  #fff4ef;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row1_col1 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row1_col2 {
#             background-color:  #f34c37;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row1_col3 {
#             background-color:  #b11218;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row1_col4 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row1_col5 {
#             background-color:  #fff3ed;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row1_col6 {
#             background-color:  #fff4ef;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row1_col7 {
#             background-color:  #fff4ef;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row1_col8 {
#             background-color:  #eb372a;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row1_col9 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row2_col0 {
#             background-color:  #ffefe8;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row2_col1 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row2_col2 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row2_col3 {
#             background-color:  #fee0d2;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row2_col4 {
#             background-color:  #fff3ed;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row2_col5 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row2_col6 {
#             background-color:  #fff4ee;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row2_col7 {
#             background-color:  #fff4ef;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row2_col8 {
#             background-color:  #feeae1;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row2_col9 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row3_col0 {
#             background-color:  #fff2eb;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row3_col1 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row3_col2 {
#             background-color:  #feeae1;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row3_col3 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row3_col4 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row3_col5 {
#             background-color:  #fff0e9;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row3_col6 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row3_col7 {
#             background-color:  #fff4ef;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row3_col8 {
#             background-color:  #fff0e8;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row3_col9 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row4_col0 {
#             background-color:  #fff0e9;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row4_col1 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row4_col2 {
#             background-color:  #fee3d6;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row4_col3 {
#             background-color:  #fedfd0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row4_col4 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row4_col5 {
#             background-color:  #ffefe8;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row4_col6 {
#             background-color:  #ffeee6;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row4_col7 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row4_col8 {
#             background-color:  #fc8d6d;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row4_col9 {
#             background-color:  #fff0e9;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row5_col0 {
#             background-color:  #fee3d7;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row5_col1 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row5_col2 {
#             background-color:  #ffefe8;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row5_col3 {
#             background-color:  #fc8060;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row5_col4 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row5_col5 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row5_col6 {
#             background-color:  #fff4ef;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row5_col7 {
#             background-color:  #fff4ef;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row5_col8 {
#             background-color:  #fcbca2;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row5_col9 {
#             background-color:  #fff4ef;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row6_col0 {
#             background-color:  #fee3d6;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row6_col1 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row6_col2 {
#             background-color:  #fcab8f;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row6_col3 {
#             background-color:  #ffece4;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row6_col4 {
#             background-color:  #fff2eb;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row6_col5 {
#             background-color:  #fee3d7;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row6_col6 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row6_col7 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row6_col8 {
#             background-color:  #fee8dd;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row6_col9 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row7_col0 {
#             background-color:  #feeae1;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row7_col1 {
#             background-color:  #fff5f0;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row7_col2 {
#             background-color:  #fcb99f;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row7_col3 {
#             background-color:  #fc8a6a;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row7_col4 {
#             background-color:  #fff1ea;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row7_col5 {
#             background-color:  #fff3ed;
#         }    #T_9a431230_c51e_11eb_92d6_f104706c96b6row7_col6 {
#             bac

# %%
h_data = """.877	.007	.007	.022	.004	.015	.060	.000	.004	.004
.014	.782	.047	.004	.036	.047	.014	.029	.007	.018
.029	.029	.681	.007	.018 	.000	.040	.029	.152	.015
.149	.022	.004	.732	.004	.011	.030	.007	.041	.000
.014	.026	.043	.014	.669	.079	.007	.007	.126	.014
.025	.014	.007	.011	.097	.633	.004	.155	.011	.043
.269	.004	.021	.021	.007	.000	.667	.000	.004	.007
.011	.028	.028	.018	.018	.070	.011	.577	.067	.172
.025	.029	.111	.046	.082	.011	.021	.082	.550	.043
.018	.004	.007	.011	.007	.018	.025	.071	.021	.818"""

# %%
h_data_f = [i.split('\t') for i in h_data.split('\n')]

# %%
for i in range(len(h_data_f)):
    for j in range(len(h_data_f[i])):
        h_data_f[i][j] = float(h_data_f[i][j])
